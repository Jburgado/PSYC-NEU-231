# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# 1) From the "tips" dataset
#     1. add a percentage tip column to the dataset
#     2. visualize the relationship between tip percentage, with day of week and time
#     3. visualize tip ~ day, time, and number of people (which function allows three variables independent variables at once?)

# %%
#importing the seaborn package
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading tips dataset and visualizing data
tips = sns.load_dataset('tips')
tips.head()

#adding new column with percentage tip
tips['tip_percentage'] = 100 * tips['tip'] / tips['total_bill']

#visualize relationship between percentage with day of week and time
sns.pointplot(x='day',y='tip_percentage',hue='time',data=tips)
# Out:
# C:\Users\Jilly\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#visualizing 3 variables - party size, day, time
sns.catplot(x='day',y='tip_percentage',hue='time',col='size',data=tips,kind='point')
plt.show()
# Out:
# C:\Users\Jilly\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.PairGrid(tips, y_vars="tip_percentage",
                 x_vars=["size", "day", "time"],
                 height=5, aspect=.5)

# Draw a seaborn pointplot onto each Axes
g.map(sns.pointplot, scale=1.3, errwidth=4, color="xkcd:plum")
# Out:
# C:\Users\Jilly\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# 2) Find an interesting trend in the "exercise" dataset

# %%
exercise = sns.load_dataset('exercise')
exercise.head()

sns.pointplot(x='time',y='pulse',data=exercise)
plt.show()
sns.pointplot(x='time',y='pulse',data=exercise,hue='kind')
plt.show()
# Out:
# C:\Users\Jilly\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
